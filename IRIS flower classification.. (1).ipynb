# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data=df.groupby('Species')

# %%
data.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#              Species
# 0        Iris-setosa
# 1        Iris-setosa
# 2        Iris-setosa
# 3        Iris-setosa
# 4        Iris-setosa
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# 100   Iris-virginica
# 101   Iris-virginica
# 102   Iris-virginica
# 103   Iris-virginica
# 104   Iris-virginica

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# 2.visualizing the dataset

# %%
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250ccb73760>,
#   <matplotlib.lines.Line2D at 0x250ccb73a30>],
#  'caps': [<matplotlib.lines.Line2D at 0x250ccb73d00>,
#   <matplotlib.lines.Line2D at 0x250ccb73fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250ccb62310>],
#  'medians': [<matplotlib.lines.Line2D at 0x250cd2312e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250cd2315b0>],
#  'means': []}

# %%
plt.boxplot(df['SepalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250cd2a3430>,
#   <matplotlib.lines.Line2D at 0x250cd2a3700>],
#  'caps': [<matplotlib.lines.Line2D at 0x250cd2a39d0>,
#   <matplotlib.lines.Line2D at 0x250cd2a3ca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250cd2a3160>],
#  'medians': [<matplotlib.lines.Line2D at 0x250cd2a3f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250cd2b1280>],
#  'means': []}

# %%
plt.boxplot(df['PetalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250cd304c10>,
#   <matplotlib.lines.Line2D at 0x250cd304ee0>],
#  'caps': [<matplotlib.lines.Line2D at 0x250cd3141f0>,
#   <matplotlib.lines.Line2D at 0x250cd3144c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250cd304940>],
#  'medians': [<matplotlib.lines.Line2D at 0x250cd314790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250cd314a60>],
#  'means': []}

# %%
plt.boxplot(df['PetalWidthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250cd376550>,
#   <matplotlib.lines.Line2D at 0x250cd376820>],
#  'caps': [<matplotlib.lines.Line2D at 0x250cd376af0>,
#   <matplotlib.lines.Line2D at 0x250cd376dc0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250cd376280>],
#  'medians': [<matplotlib.lines.Line2D at 0x250cd3850d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250cd3853a0>],
#  'means': []}

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
#  3.data preparation

# %%
df.drop('Id',axis=1,inplace=True)

# %%
sp={'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3}

# %%
df.Species=[sp[i]for i in df.Species]

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        1
# 1              4.9           3.0            1.4           0.2        1
# 2              4.7           3.2            1.3           0.2        1
# 3              4.6           3.1            1.5           0.2        1
# 4              5.0           3.6            1.4           0.2        1
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        3
# 146            6.3           2.5            5.0           1.9        3
# 147            6.5           3.0            5.2           2.0        3
# 148            6.2           3.4            5.4           2.3        3
# 149            5.9           3.0            5.1           1.8        3
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %% [markdown]
# 3.traning model

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.9304223675331595

# %%
model.coef_
# Out:
# array([-0.10974146, -0.04424045,  0.22700138,  0.60989412])

# %%
model.intercept_
# Out:
# 1.1920839948281436

# %% [markdown]
# 4.making prediction

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# 5.model Evolution

# %%
print("Mean squared error: %.2f"%np.mean((y_pred-y_test)**2))
# Out:
# Mean squared error: 0.04
